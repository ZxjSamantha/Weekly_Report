# %%
import mne

# %%
path = '/home/xinjie/xinjie/00_experiment/BCICompetitionIV2a/BCICIV_2a/train/A01T.gdf'
A01T = mne.io.read_raw_gdf(path)
# The workspace of A01T contains two variables [s, h]
# s: signals, the signal variable contains 25 channels (22 EEG + 3 ECOG signals)
# h: a header structure h
# Out:
# Extracting EDF parameters from /home/xinjie/xinjie/00_experiment/BCICompetitionIV2a/BCICIV_2a/train/A01T.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# /home/xinjie/anaconda3/envs/eegnet/lib/python3.8/site-packages/mne/io/edf/edf.py:1044: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, UINT8).tolist()[0]
# <ipython-input-5-88ed2300d266>:2: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   A01T = mne.io.read_raw_gdf(path)

# %%
mne.events_from_annotations(A01T)
# Out:
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# (array([[     0,      0,      5],
#         [     0,      0,      3],
#         [ 29683,      0,      5],
#         ...,
#         [670550,      0,      6],
#         [670550,      0,      1],
#         [671050,      0,      7]]),
#  {'1023': 1,
#   '1072': 2,
#   '276': 3,
#   '277': 4,
#   '32766': 5,
#   '768': 6,
#   '769': 7,
#   '770': 8,
#   '771': 9,
#   '772': 10})

# %%
A01T.crop(tmax=60).load_data()
# Out:
# Reading 0 ... 15000  =      0.000 ...    60.000 secs...
# <RawGDF | A01T.gdf, 25 x 15001 (60.0 s), ~2.9 MB, data loaded>

# %%
A01T.annotations
# Out:
# <Annotations | 2 segments: 276 (1), 32766 (1)>

# %%
A01T.to_data_frame() # 22+3 channels
# Out:
#         time     EEG-Fz      EEG-0      EEG-1      EEG-2      EEG-3  \
# 0          0 -21.142578 -23.681641 -21.484375 -25.146484 -25.732422
# 1          4 -21.923828 -23.925781 -24.316406 -25.341797 -26.074219
# 2          8 -15.625000 -19.726562 -18.847656 -21.582031 -20.751953
# 3         12 -16.699219 -13.720703 -20.361328 -20.849609 -24.169922
# 4         16 -19.335937 -17.626953 -20.410156 -26.464844 -27.392578
# ...      ...        ...        ...        ...        ...        ...
# 14996  59984  -1.318359  -1.464844  -1.757812  -0.048828   0.439453
# 14997  59988  -4.296875  -3.027344  -4.150391  -4.248047  -3.759766
# 14998  59992  -3.320312   2.880859  -2.832031  -1.562500  -4.492188
# 14999  59996  -3.710938  -3.125000  -3.955078  -7.763672  -5.859375
# 15000  60000  -2.685547   4.980469  -2.001953  -2.929688  -4.980469
#
#            EEG-4      EEG-5     EEG-C3      EEG-6  ...     EEG-11     EEG-12  \
# ...
